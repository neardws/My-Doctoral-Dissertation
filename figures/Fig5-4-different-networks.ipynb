# %%
import matplotlib.pyplot as plt
import numpy as np
import brewer2mpl
bmap = brewer2mpl.get_map('Paired', 'qualitative', 10)
colors = bmap.mpl_colors

colors = colors[0: 10]

fig_title = ['(a)', '(a)', '(b)']

labels = ['RA', 'D4PG', 'MAD4PG', 'MAMO']

markers = ['*', 'd', 's', '^', '^']
font_size = 50
xticks_font_size = 1
legend_size = 40
markersize = 30
plt.figure(figsize=(50, 17))            # 确定图像画布的大小
plt.rcParams['font.family'] = 'Times New Roman'  # 设置字体
x_label = 'Number of neurons in the hidden layers'

x_vals = [1, 2, 3, 4, 5]
new_x_index = ['[64, 32]\n[128, 64]', '[128, 64]\n[256, 128]', '[256, 128]\n[512, 256]', '[512, 256]\n[1024, 512]', '[1024, 512]\n[2048, 1024]']

#################################################################### #################################################################
# plt.subplot(1, 2, 1)                        # 将画布分为两列

# plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
# plt.ylabel('QPUC', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
# plt.title(fig_title[0], fontsize=font_size, y=-0.2)     # 图的title


# vcpsq = [162.5600983242963, 233.32818453206104, 245.4123682830202, 231.2636014877593, 154.34698001258738]
# vcpsc = [267.33106407052645, 279.048642014847, 281.14356385949003, 272.31824494273746, 174.3003092758866]
# mamo = [0, 0, 0, 0, 0]

# for i in range(5):
#     mamo[i] = vcpsq[i] / (300 - vcpsc[i])


# plt.grid()

# plt.plot(x_vals, mamo, linestyle=":", marker=markers[4], markersize=markersize, color=colors[6], label=labels[3], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[7])

# ax = plt.gca()
# plt.xticks(x_vals, new_x_index, fontsize=1)

# plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
# plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
#################################################################### #################################################################
plt.subplot(1, 2, 1) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('Quality and profit', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.22)     # 图的title

vcpsq = [162.5600983242963, 233.32818453206104, 245.4123682830202, 231.2636014877593, 154.34698001258738]
vcpsc = [267.33106407052645, 279.048642014847, 281.14356385949003, 272.31824494273746, 174.3003092758866]

plt.plot(x_vals, vcpsq, linestyle="-", marker="+", markersize=markersize, color='black', label="Quality", linewidth=5.0, markerfacecolor='none', markeredgewidth = 10.0, markeredgecolor = 'black')
plt.plot(x_vals, vcpsc, linestyle=":", marker="x", markersize=markersize, color='black', label="Profit", linewidth=5.0, markerfacecolor='none', markeredgewidth = 10.0, markeredgecolor = 'black')

plt.grid()

plt.xticks(x_vals, new_x_index, fontsize=1)

plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

#################################################################### #################################################################
plt.subplot(1, 2, 2) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('AT, ASC, and ATC', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.22)     # 图的title

diff = 1

colors = ['white', 'lightgray', 'black']
edgecolor = 'black'

x = np.arange(1, 6, 1)

width = diff * 0.18
small_width = diff * 0.04
label_text_size = 28

at = [0.46896478812840636, 0.1064335248023899, 0.0664344863705233, 0.11981801844804416, 0.6320612788020037]
asc = [0.17595231984012197, 0.1381834228759392, 0.131038247391626, 0.179238845795553, 0.5201879048628166]
atc = [0.09628881290549086, 0.03641122700033508, 0.03968007878976352, 0.050746464205444146, 0.3811190416476524]

plt.bar(x - width - 2 * small_width, at, width, label='AT', hatch="/", color=colors[0], edgecolor=colors[2])
plt.bar(x - width + 4 * small_width, asc, width, label='ASC', hatch="+", color=colors[1], edgecolor=colors[2])
plt.bar(x + 5.5 * small_width, atc, width, label='ATC', hatch="-", color=colors[2], edgecolor=colors[2])


plt.xticks(x_vals, new_x_index, fontsize=1)

plt.grid()
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=3)     # 显示图例，loc=0表示图例会根据图片情况自动摆放





plt.subplots_adjust(wspace =0.2, hspace =0.25)#调整子图间距
plt.savefig("Fig5-4-different-networks.pdf", bbox_inches='tight')
plt.show()
