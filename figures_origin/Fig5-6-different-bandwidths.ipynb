# %%
import matplotlib.pyplot as plt
import numpy as np
import brewer2mpl
bmap = brewer2mpl.get_map('Paired', 'qualitative', 10)
colors = bmap.mpl_colors

colors = colors[0: 10]

fig_title = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)']

labels = ['RA', 'D4PG', 'MAD4PG', 'MAMO']

markers = ['*', 'd', 's', '^', '^']
font_size = 45
legend_size = 35
markersize = 25
plt.figure(figsize=(30, 28))            # 确定图像画布的大小
plt.rcParams['font.family'] = 'Times New Roman'  # 设置字体
x_label = 'Bandwidth (MHz)'
#################################################################### #################################################################
plt.subplot(3, 2, 1)                        # 将画布分为两列

plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('QPUC', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[0], fontsize=font_size, y=-0.32)     # 图的title
x_vals = [1, 1.5, 2, 2.5, 3]

ra_cq = [221.2348231572297, 225.94558022032388, 230.9602806317781, 232.9272257258669, 236.74950285709573]
d3pg_cq = [260.02895220883204, 261.930003778295, 263.5256663049404, 266.0573089855218, 278.40111865004013]
madrl_cq = [249.99099663489645, 247.72985509787424, 251.36963368518687, 248.6813686952037, 247.95297290583227]
mamodrl_cq = [231.74749200821037, 233.383737572, 245.4123682830202, 248.65852678187443, 260.341118777284]

ra_cc = [181.65288298261714, 188.11846255616155, 198.431242902245, 200.60608958207712, 205.321813739242]
d3pg_cc = [261.9028844922433, 259.7012284316506, 254.44822437688902, 249.1069998408073, 244.46606367081648]
madrl_cc = [163.96073612848292, 189.9033042835146, 203.1538561578501, 199.5656318874922, 194.67424798177356]
mamodrl_cc = [253.1211751143199, 270.4093885167952, 281.14356385949003, 281.8261897622806, 289.1014313332302]

ra = [0, 0, 0, 0, 0]
d3pg = [0, 0, 0, 0, 0]
madrl = [0, 0, 0, 0, 0]
mamo = [0, 0, 0, 0, 0]

for i in range(5):
    ra[i] = ra_cq[i] / (300 - ra_cc[i])
    d3pg[i] =d3pg_cq[i] / (300 - d3pg_cc[i])
    madrl[i] = madrl_cq[i] / (300 - madrl_cc[i])
    mamo[i] = mamodrl_cq[i] / (300 - mamodrl_cc[i])

plt.plot(x_vals, ra, linestyle=":", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[1])
plt.plot(x_vals, d3pg, linestyle=":", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[3])
plt.plot(x_vals, madrl, linestyle=":", marker=markers[2], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[5])
plt.plot(x_vals, mamo, linestyle=":", marker=markers[4], markersize=markersize, color=colors[6], label=labels[3], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[7])

ra_improvement = 0
d3pg_improvement = 0
madrl_improvement = 0

for i in range(5):
    ra_improvement += (mamo[i] - ra[i]) / ra[i]
    d3pg_improvement += (mamo[i] - d3pg[i]) / d3pg[i]
    madrl_improvement += (mamo[i] - madrl[i]) / madrl[i]
    
print(ra_improvement / 5)
print(d3pg_improvement / 5)
print(madrl_improvement / 5)
    
plt.grid()

plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放
#################################################################### #################################################################
plt.subplot(3, 2, 2) 
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('PPUQ', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[1], fontsize=font_size, y=-0.32)     # 图的title


ra_cq = [221.2348231572297, 225.94558022032388, 230.9602806317781, 232.9272257258669, 236.74950285709573]
d3pg_cq = [260.02895220883204, 261.930003778295, 263.5256663049404, 266.0573089855218, 278.40111865004013]
madrl_cq = [249.99099663489645, 247.72985509787424, 251.36963368518687, 248.6813686952037, 247.95297290583227]
mamodrl_cq = [231.74749200821037, 233.383737572, 245.4123682830202, 248.65852678187443, 260.341118777284]

ra_cc = [181.65288298261714, 188.11846255616155, 198.431242902245, 200.60608958207712, 205.321813739242]
d3pg_cc = [261.9028844922433, 259.7012284316506, 254.44822437688902, 249.1069998408073, 244.46606367081648]
madrl_cc = [163.96073612848292, 189.9033042835146, 203.1538561578501, 199.5656318874922, 194.67424798177356]
mamodrl_cc = [253.1211751143199, 270.4093885167952, 281.14356385949003, 281.8261897622806, 289.1014313332302]

ra = [0, 0, 0, 0, 0]
d3pg = [0, 0, 0, 0, 0]
madrl = [0, 0, 0, 0, 0]
mamo = [0, 0, 0, 0, 0]

ra_improvement = 0
d3pg_improvement = 0
madrl_improvement = 0

for i in range(5):
    ra[i] = ra_cc[i] / ra_cq[i]
    d3pg[i] =d3pg_cc[i] / d3pg_cq[i]
    madrl[i] = madrl_cc[i] / madrl_cq[i]
    mamo[i] = mamodrl_cc[i] / mamodrl_cq[i]

for i in range(5):
    ra_improvement += (mamo[i] - ra[i]) / ra[i]
    d3pg_improvement += (mamo[i] - d3pg[i]) / d3pg[i]
    madrl_improvement += (mamo[i] - madrl[i]) / madrl[i]
    
print(ra_improvement / 5)
print(d3pg_improvement / 5)
print(madrl_improvement / 5)

plt.plot(x_vals, ra, linestyle=":", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[1])
plt.plot(x_vals, d3pg, linestyle=":", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[3])
plt.plot(x_vals, madrl, linestyle=":", marker=markers[2], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[5])
plt.plot(x_vals, mamo, linestyle=":", marker=markers[4], markersize=markersize, color=colors[6], label=labels[3], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[7])
plt.grid()
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

#################################################################### #################################################################

plt.subplot(3, 2, 3)
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('AT', fontsize=font_size)         # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[2], fontsize=font_size, y=-0.32)     # 图的title

ra_avt = [0.23143469931451094, 0.2347721960682186, 0.19550648107412585, 0.21036154384574282, 0.20004013064914145]
d3pg_avt = [0.14892963845221785, 0.11436340078780091, 0.11538770771201082, 0.09440717252101814, 0.0393829255276881]
madrl_avt = [0.169579294039104, 0.157499545126598, 0.1561943366987121, 0.1548977202302712, 0.1601903890198381]
mamodrl_avt = [0.0915921603516931, 0.08110818143719596, 0.0664344863705233, 0.0593681439091098, 0.0383689491782293]

plt.plot(x_vals, ra_avt, linestyle=":", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[1])
plt.plot(x_vals, d3pg_avt, linestyle=":", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[3])
plt.plot(x_vals, madrl_avt, linestyle=":", marker=markers[2], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[5])
plt.plot(x_vals, mamodrl_avt, linestyle=":", marker=markers[4], markersize=markersize, color=colors[6], label=labels[3], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[7])

plt.grid()

# plt.ylim(0, 0.7)                    # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=2, bbox_to_anchor=(0.05, 0.9), fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放


#################################################################### #################################################################
plt.subplot(3, 2, 4)                       # 将画布分为两列
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('AR', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[3], fontsize=font_size, y=-0.32)     # 图的title

ra_avr = [0.20598277310924384, 0.21449479166666663, 0.21469583333333328, 0.2270966666666669, 0.2436595238095238]
d3pg_avr = [0.04278993055555551, 0.05287096774193536, 0.05837986111111107, 0.08277222222222218, 0.09918205128205117]
madrl_avr = [0.2529166666666669, 0.3089583333333333, 0.2564444444444446, 0.2901666666666667, 0.3226666666666665]
mamodrl_avr = [0.002506249999999996, 0.0, 0.0, 0.0, 0.0]

plt.plot(x_vals, ra_avr, linestyle=":", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[1])
plt.plot(x_vals, d3pg_avr, linestyle=":", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[3])
plt.plot(x_vals, madrl_avr, linestyle=":", marker=markers[2], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[5])
plt.plot(x_vals, mamodrl_avr, linestyle=":", marker=markers[4], markersize=markersize, color=colors[6], label=labels[3], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[7])

plt.grid()
# plt.ylim(0, 1.7)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

################################################################################
plt.subplot(3, 2, 5)                       # 将画布分为两列
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('ASC', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[4], fontsize=font_size, y=-0.32)     # 图的title

ra_avsc = [0.4617757768348732, 0.4713016872111327, 0.4666399544866637, 0.4689667909429361, 0.4744919574502896]
d3pg_avsc = [0.18084045666039333, 0.22649595641707226, 0.23816952224093066, 0.3133883079828469, 0.32047019160432916]
madrl_avsc = [0.5389767679534665, 0.459587024911733, 0.4924105378391942, 0.5137933450534221, 0.6003814073794803]
mamodrl_avsc = [0.23333500095821605, 0.1780142146877779, 0.131038247391626, 0.1117683398578979, 0.0761844471482361]

plt.plot(x_vals, ra_avsc, linestyle=":", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[1])
plt.plot(x_vals, d3pg_avsc, linestyle=":", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[3])
plt.plot(x_vals, madrl_avsc, linestyle=":", marker=markers[2], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[5])
plt.plot(x_vals, mamodrl_avsc, linestyle=":", marker=markers[4], markersize=markersize, color=colors[6], label=labels[3], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[7])

plt.grid()
# plt.ylim(0, 1.7)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放

################################################################################
plt.subplot(3, 2, 6)                       # 将画布分为两列
plt.xlabel(x_label, fontsize=font_size)                          # x轴的label
plt.ylabel('ATC', fontsize=font_size)          # y轴的label     备注（plot所有的原件都可以加fontsize属性）
plt.title(fig_title[5], fontsize=font_size, y=-0.32)     # 图的title

ra_avtc = [0.421458811755362, 0.3474961248208547, 0.2725189588279612, 0.23748603396832585, 0.20714501138936048]
d3pg_avtc = [0.11524054062646849, 0.11223867739610509, 0.10092650002775551, 0.08289165611487173, 0.061129001036066465]
madrl_avtc = [0.468225430975842, 0.3034062727256456, 0.186418438623166, 0.1780763892174763, 0.1159998594390725]
mamodrl_avtc = [0.15606874808911894, 0.0685742143389296, 0.03968007878976352, 0.0260987204459562, 0.0146369584081787]

plt.plot(x_vals, ra_avtc, linestyle=":", marker=markers[0], markersize=markersize, color=colors[0], label=labels[0], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[1])
plt.plot(x_vals, d3pg_avtc, linestyle=":", marker=markers[1], markersize=markersize, color=colors[2], label=labels[1], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[3])
plt.plot(x_vals, madrl_avtc, linestyle=":", marker=markers[2], markersize=markersize, color=colors[4], label=labels[2], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[5])
plt.plot(x_vals, mamodrl_avtc, linestyle=":", marker=markers[4], markersize=markersize, color=colors[6], label=labels[3], linewidth=5.0, markerfacecolor='none', markeredgewidth = 5.0, markeredgecolor = colors[7])

plt.grid()
# plt.ylim(0, 1.7)                     # 设置y轴的取值范围，如设置（0,5）则y轴坐标为从0开始，到5结束
# 刻度值字体大小设置
plt.tick_params(labelsize=font_size)        # 设置坐标轴上刻度的字体大小
plt.legend(loc=0, fontsize = legend_size, ncol=2)     # 显示图例，loc=0表示图例会根据图片情况自动摆放



plt.subplots_adjust(wspace =0.2, hspace =0.35)#调整子图间距
plt.savefig("Fig5-6-different-bandwidths.pdf", bbox_inches='tight')
plt.show()
# Out:
# 4.532947120311063
# 1.3139212418511532
# 4.376490142728467
# 0.33033791832856424
# 0.1829192240397749
# 0.4841970311378935
